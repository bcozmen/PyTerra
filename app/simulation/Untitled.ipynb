# %%
from world_map import WorldMap
from land import City
import numpy as np

# %%
np.random.seed(43)
world = WorldMap(size=2**10+1, num_rivers=8, sea_level=0.18)
city = City(1, world.maps, (400,600))

city.grow(amount=1000)
world.plot_2d("terrain")

# %%
city.grow(amount=5000)
world.plot_2d("terrain")

# %%
world.maps["city"] = np.zeros_like(world.maps["city"])

# %%
wo
